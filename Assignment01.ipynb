# %%
import pandas as pd
import numpy as np

# %%
# Read data using data frame
df = pd.read_csv("C:\\Users\\hp5cd\\OneDrive\\Desktop\\ML_LAB_T1_03\\covid_19_clean_complete.csv")
df.head()
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %%
# Dropping the 'Active' column from the DataFrame
to_drop = ['Active']

df.drop(to_drop, inplace=True, axis=1)

# %%
df.head()
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered             WHO Region
# 0       0          0  Eastern Mediterranean
# 1       0          0                 Europe
# 2       0          0                 Africa
# 3       0          0                 Europe
# 4       0          0                 Africa

# %%
df['Long'].is_unique
# Out:
# False

# %%
df['Index'] = range(1, len(df)+1)

# %%
df.head()
# Out:
#   Province/State Country/Region       Lat       Long        Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953  2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300  2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600  2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800  2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900  2020-01-22          0
#
#    Deaths  Recovered             WHO Region  Index
# 0       0          0  Eastern Mediterranean      1
# 1       0          0                 Europe      2
# 2       0          0                 Africa      3
# 3       0          0                 Europe      4
# 4       0          0                 Africa      5

# %%
# To check unique column
df['Index'].is_unique
# Out:
# True

# %%
# Set the 'Index' column as the index for the DataFrame
df = df.set_index('Index')
df.head()
# Out:
#       Province/State Country/Region       Lat       Long        Date  \
# Index
# 1                NaN    Afghanistan  33.93911  67.709953  2020-01-22
# 2                NaN        Albania  41.15330  20.168300  2020-01-22
# 3                NaN        Algeria  28.03390   1.659600  2020-01-22
# 4                NaN        Andorra  42.50630   1.521800  2020-01-22
# 5                NaN         Angola -11.20270  17.873900  2020-01-22
#
#        Confirmed  Deaths  Recovered             WHO Region
# Index
# 1              0       0          0  Eastern Mediterranean
# 2              0       0          0                 Europe
# 3              0       0          0                 Africa
# 4              0       0          0                 Europe
# 5              0       0          0                 Africa

# %%
# Access the row with index label 206 in the DataFrame
df.loc[206]
# Out:
# Province/State                NaN
# Country/Region            Taiwan*
# Lat                          23.7
# Long                        121.0
# Date                   2020-01-22
# Confirmed                       1
# Deaths                          0
# Recovered                       0
# WHO Region        Western Pacific
# Name: 206, dtype: object

# %%
# Get the count of each data type present in the DataFrame
df.dtypes.value_counts()
# Out:
# object     4
# int64      3
# float64    2
# Name: count, dtype: int64
